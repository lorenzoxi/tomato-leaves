# %%
from torchvision import datasets, transforms
import os
from torchvision.datasets import ImageFolder
from PIL import Image
import random

# %%
# PRINT THE NUMBER OF IMAGES IN THE DATASETS 

dataset_path = './dataset-tomatoes'
train_path = os.path.join(dataset_path, 'train')
val_path = os.path.join(dataset_path, 'validation')
test_path = os.path.join(dataset_path, 'test')


train_dataset = ImageFolder(root=train_path)
val_dataset = ImageFolder(root=val_path)
test_dataset = ImageFolder(root=test_path)

print(f"Number of training images: {len(train_dataset)}")
print(f"Number of validation images: {len(val_dataset)}")
print(f"Number of test images: {len(test_dataset)}")

total = len(train_dataset) + len(val_dataset) + len(test_dataset)
print(f"Total number of images: {total}")
# Out:
# Number of training images: 14404
# Number of validation images: 1796
# Number of test images: 1796
# Total number of images: 17996

# %%
path = './dataset-tomatoes'

full_dataset = ImageFolder(root=path)

print(len(full_dataset))

classes = full_dataset.classes

for i in range(len(classes)):
    print(f"Number of images in {classes[i]}: {len(os.listdir(os.path.join(path, classes[i])))}")

# %%
# === SPLITTING THE DATASET === 

import os
import shutil
import json
from random import shuffle

data_config = '''
{
    "Tomato___Bacterial_spot": {"total": 2406, "training_set": 1930, "validation_set": 235, "test_set": 241},
    "Tomato___Early_blight": {"total": 1214, "training_set": 966, "validation_set": 131, "test_set": 117},
    "Tomato___Late_blight": {"total": 2129, "training_set": 1710, "validation_set": 210, "test_set": 209},
    "Tomato___Leaf_Mold": {"total": 1244, "training_set": 999, "validation_set": 120, "test_set": 125},
    "Tomato___Septoria_leaf_spot": {"total": 2204, "training_set": 1771, "validation_set": 210, "test_set": 223},
    "Tomato___Tomato_mosaic_virus": {"total": 634, "training_set": 509, "validation_set": 66, "test_set": 59},
    "Tomato___Tomato_Yellow_Leaf_Curl_Virus": {"total": 6179, "training_set": 4930, "validation_set": 624, "test_set": 625},
    "Tomato___healthy": {"total": 1986, "training_set": 1589, "validation_set": 200, "test_set": 197}
}
'''
config = json.loads(data_config)

dataset_path = './dataset-tomatoes/'

for set_type in ['train', 'validation', 'test']:
    set_path = os.path.join(dataset_path, set_type)
    if not os.path.exists(set_path):
        os.makedirs(set_path)

for class_name, sets in config.items():
    class_dir = os.path.join(dataset_path, class_name)
    images = os.listdir(class_dir)
    shuffle(images)  

    for set_type in ['train', 'validation', 'test']:
        set_class_path = os.path.join(dataset_path, set_type, class_name)
        if not os.path.exists(set_class_path):
            os.makedirs(set_class_path)

    validation_count = sets['validation_set']
    test_count = sets['test_set']
    training_count = sets['training_set']

    validation_images = images[:validation_count]
    test_images = images[validation_count:validation_count + test_count]
    training_images = images[validation_count + test_count:]

    for image in validation_images:
        shutil.copy(os.path.join(class_dir, image), os.path.join(dataset_path, 'validation', class_name))
    for image in test_images:
        shutil.copy(os.path.join(class_dir, image), os.path.join(dataset_path, 'test', class_name))
    for image in training_images:
        shutil.copy(os.path.join(class_dir, image), os.path.join(dataset_path, 'train', class_name))

# %%
# === PRINTING THE NUMBER OF IMAGES IN EACH CLASS ===
import os
path = './dataset-tomatoes/train'
full_dataset = ImageFolder(root=path)

print(len(full_dataset))

classes = full_dataset.classes

for i in range(len(classes)):
    print(f"Number of images in {classes[i]}: {len(os.listdir(os.path.join(path, classes[i])))}")
# Out:
# 14404
# Number of images in Tomato___Bacterial_spot: 1930
# Number of images in Tomato___Early_blight: 966
# Number of images in Tomato___Late_blight: 1710
# Number of images in Tomato___Leaf_Mold: 999
# Number of images in Tomato___Septoria_leaf_spot: 1771
# Number of images in Tomato___Tomato_Yellow_Leaf_Curl_Virus: 4930
# Number of images in Tomato___Tomato_mosaic_virus: 509
# Number of images in Tomato___healthy: 1589

# %%
# === AUGMENTING THE DATASET ===
import os
import random
from torchvision import transforms
from torchvision.datasets import ImageFolder
from PIL import Image
import json

# Load JSON configuration
data_config = '''
{
    "Tomato___Bacterial_spot": {"total": 2406, "training_set": 1930, "validation_set": 235, "test_set": 241},
    "Tomato___Early_blight": {"total": 1214, "training_set": 966, "validation_set": 131, "test_set": 117},
    "Tomato___Late_blight": {"total": 2129, "training_set": 1710, "validation_set": 210, "test_set": 209},
    "Tomato___Leaf_Mold": {"total": 1244, "training_set": 999, "validation_set": 120, "test_set": 125},
    "Tomato___Septoria_leaf_spot": {"total": 2204, "training_set": 1771, "validation_set": 210, "test_set": 223},
    "Tomato___Tomato_mosaic_virus": {"total": 634, "training_set": 509, "validation_set": 66, "test_set": 59},
    "Tomato___Tomato_Yellow_Leaf_Curl_Virus": {"total": 6179, "training_set": 4930, "validation_set": 624, "test_set": 625},
    "Tomato___healthy": {"total": 1986, "training_set": 1589, "validation_set": 200, "test_set": 197}
}
'''
config = json.loads(data_config)

dataset_path = './dataset-tomatoes/train'
full_dataset = ImageFolder(root=dataset_path)
classes = full_dataset.classes

# Define transformations
transformations = {
    "horizontal_flip": transforms.RandomHorizontalFlip(p=1),
    "color_jitter": transforms.ColorJitter(brightness=0, contrast=0, saturation=0, hue=0.5),
    "contrast_enhancement": transforms.ColorJitter(brightness=0, contrast=1.5, saturation=0, hue=0),
    "saturation_enhancement": transforms.ColorJitter(brightness=0, contrast=0, saturation=1.5, hue=0),
    "brightness_enhancement": transforms.ColorJitter(brightness=1.5, contrast=0, saturation=0, hue=0),
    "rotation": transforms.RandomRotation((45, 45)),
    "resized_crop": transforms.RandomResizedCrop(size=(224, 224), scale=(0.8, 1.0), ratio=(1.0, 1.0))
}

transformations = list(transformations.values())
print(transformations)

# Augment images for each class to meet training set requirements
for class_name in classes:
    class_folder = os.path.join(dataset_path, class_name)
    images = [os.path.join(class_folder, img) for img in os.listdir(class_folder) if img.lower().endswith(('.jpg', '.jpeg', '.png'))]
    current_count = len(images)
    training_target = config[class_name]['training_set']

    needed_augmentations = training_target - current_count
    
    print(f"Augmenting {class_name} with {needed_augmentations} images")
    print("In total we ll have", current_count + needed_augmentations, "images")
    print("-------------------")
    
    for i in range(needed_augmentations):
        print("Augmenting image", i+1)
        random_image_path = random.choice(images)
        image = Image.open(random_image_path)
        transform = transformations[i % len(transformations)]
        transformed_image = transform(image)
        suffix = transform.__class__.__name__.lower()
        save_path = os.path.join(class_folder, f"img_{suffix}_{i+1}_{class_name}.jpg")
        transformed_image.save(save_path)

print("Augmentation complete!")
# Out:
# [RandomHorizontalFlip(p=1), ColorJitter(brightness=None, contrast=None, saturation=None, hue=(-0.5, 0.5)), ColorJitter(brightness=None, contrast=(0.0, 2.5), saturation=None, hue=None), ColorJitter(brightness=None, contrast=None, saturation=(0.0, 2.5), hue=None), ColorJitter(brightness=(0.0, 2.5), contrast=None, saturation=None, hue=None), RandomRotation(degrees=[45.0, 45.0], interpolation=nearest, expand=False, fill=0), RandomResizedCrop(size=(224, 224), scale=(0.8, 1.0), ratio=(1.0, 1.0), interpolation=bilinear, antialias=warn)]
# Augmenting Tomato___Bacterial_spot with 178 images
# In total we ll have 1930 images
# -------------------
# Augmenting image 1
# Augmenting image 2
# Augmenting image 3
# Augmenting image 4
# Augmenting image 5
# Augmenting image 6
# Augmenting image 7
# Augmenting image 8
# Augmenting image 9
# Augmenting image 10
# Augmenting image 11
# Augmenting image 12
# Augmenting image 13
# Augmenting image 14
# Augmenting image 15
# Augmenting image 16
# Augmenting image 17
# Augmenting image 18
# Augmenting image 19
# Augmenting image 20
# Augmenting image 21
# Augmenting image 22
# Augmenting image 23
# Augmenting image 24
# Augmenting image 25
# Augmenting image 26
# Augmenting image 27
# Augmenting image 28
# Augmenting image 29
# Augmenting image 30
# Augmenting image 31
# Augmenting image 32
# Augmenting image 33
# Augmenting image 34
# Augmenting image 35
# Augmenting image 36
# Augmenting image 37
# Augmenting image 38
# Augmenting image 39
# Augmenting image 40
# Augmenting image 41
# Augmenting image 42
# Augmenting image 43
# Augmenting image 44
# Augmenting image 45
# Augmenting image 46
# Augmenting image 47
# Augmenting image 48
# Augmenting image 49
# Augmenting image 50
# Augmenting image 51
# Augmenting image 52
# Augmenting image 53
# Augmenting image 54
# Augmenting image 55
# Augmenting image 56
# Augmenting image 57
# Augmenting image 58
# Augmenting image 59
# Augmenting image 60
# Augmenting image 61
# Augmenting image 62
# Augmenting image 63
# Augmenting image 64
# Augmenting image 65
# Augmenting image 66
# Augmenting image 67
# Augmenting image 68
# Augmenting image 69
# Augmenting image 70
# Augmenting image 71
# Augmenting image 72
# Augmenting image 73
# Augmenting image 74
# Augmenting image 75
# Augmenting image 76
# Augmenting image 77
# Augmenting image 78
# Augmenting image 79
# Augmenting image 80
# Augmenting image 81
# Augmenting image 82
# Augmenting image 83
# Augmenting image 84
# Augmenting image 85
# Augmenting image 86
# Augmenting image 87
# Augmenting image 88
# Augmenting image 89
# Augmenting image 90
# Augmenting image 91
# Augmenting image 92
# Augmenting image 93
# Augmenting image 94
# Augmenting image 95
# Augmenting image 96
# Augmenting image 97
# Augmenting image 98
# Augmenting image 99
# Augmenting image 100
# Augmenting image 101
# Augmenting image 102
# Augmenting image 103
# Augmenting image 104
# Augmenting image 105
# Augmenting image 106
# Augmenting image 107
# Augmenting image 108
# Augmenting image 109
# Augmenting image 110
# Augmenting image 111
# Augmenting image 112
# Augmenting image 113
# Augmenting image 114
# Augmenting image 115
# Augmenting image 116
# Augmenting image 117
# Augmenting image 118
# Augmenting image 119
# Augmenting image 120
# Augmenting image 121
# Augmenting image 122
# Augmenting image 123
# Augmenting image 124
# Augmenting image 125
# Augmenting image 126
# Augmenting image 127
# Augmenting image 128
# Augmenting image 129
# Augmenting image 130
# Augmenting image 131
# Augmenting image 132
# Augmenting image 133
# Augmenting image 134
# Augmenting image 135
# Augmenting image 136
# Augmenting image 137
# Augmenting image 138
# Augmenting image 139
# Augmenting image 140
# Augmenting image 141
# Augmenting image 142
# Augmenting image 143
# Augmenting image 144
# Augmenting image 145
# Augmenting image 146
# Augmenting image 147
# Augmenting image 148
# Augmenting image 149
# Augmenting image 150
# Augmenting image 151
# Augmenting image 152
# Augmenting image 153
# Augmenting image 154
# Augmenting image 155
# Augmenting image 156
# Augmenting image 157
# Augmenting image 158
# Augmenting image 159
# Augmenting image 160
# Augmenting image 161
# Augmenting image 162
# Augmenting image 163
# Augmenting image 164
# Augmenting image 165
# Augmenting image 166
# Augmenting image 167
# Augmenting image 168
# Augmenting image 169
# Augmenting image 170
# Augmenting image 171
# Augmenting image 172
# Augmenting image 173
# Augmenting image 174
# Augmenting image 175
# Augmenting image 176
# Augmenting image 177
# Augmenting image 178
# Augmenting Tomato___Early_blight with 135 images
# In total we ll have 966 images
# -------------------
# Augmenting image 1
# Augmenting image 2
# Augmenting image 3
# Augmenting image 4
# Augmenting image 5
# Augmenting image 6
# Augmenting image 7
# Augmenting image 8
# Augmenting image 9
# Augmenting image 10
# Augmenting image 11
# Augmenting image 12
# Augmenting image 13
# Augmenting image 14
# Augmenting image 15
# Augmenting image 16
# Augmenting image 17
# Augmenting image 18
# Augmenting image 19
# Augmenting image 20
# Augmenting image 21
# Augmenting image 22
# Augmenting image 23
# Augmenting image 24
# Augmenting image 25
# Augmenting image 26
# Augmenting image 27
# Augmenting image 28
# Augmenting image 29
# Augmenting image 30
# Augmenting image 31
# Augmenting image 32
# Augmenting image 33
# Augmenting image 34
# Augmenting image 35
# Augmenting image 36
# Augmenting image 37
# Augmenting image 38
# Augmenting image 39
# Augmenting image 40
# Augmenting image 41
# Augmenting image 42
# Augmenting image 43
# Augmenting image 44
# Augmenting image 45
# Augmenting image 46
# Augmenting image 47
# Augmenting image 48
# Augmenting image 49
# Augmenting image 50
# Augmenting image 51
# Augmenting image 52
# Augmenting image 53
# Augmenting image 54
# Augmenting image 55
# Augmenting image 56
# Augmenting image 57
# Augmenting image 58
# Augmenting image 59
# Augmenting image 60
# Augmenting image 61
# Augmenting image 62
# Augmenting image 63
# Augmenting image 64
# Augmenting image 65
# Augmenting image 66
# Augmenting image 67
# Augmenting image 68
# Augmenting image 69
# Augmenting image 70
# Augmenting image 71
# Augmenting image 72
# Augmenting image 73
# Augmenting image 74
# Augmenting image 75
# Augmenting image 76
# Augmenting image 77
# Augmenting image 78
# Augmenting image 79
# Augmenting image 80
# Augmenting image 81
# Augmenting image 82
# Augmenting image 83
# Augmenting image 84
# Augmenting image 85
# Augmenting image 86
# Augmenting image 87
# Augmenting image 88
# Augmenting image 89
# Augmenting image 90
# Augmenting image 91
# Augmenting image 92
# Augmenting image 93
# Augmenting image 94
# Augmenting image 95
# Augmenting image 96
# Augmenting image 97
# Augmenting image 98
# Augmenting image 99
# Augmenting image 100
# Augmenting image 101
# Augmenting image 102
# Augmenting image 103
# Augmenting image 104
# Augmenting image 105
# Augmenting image 106
# Augmenting image 107
# Augmenting image 108
# Augmenting image 109
# Augmenting image 110
# Augmenting image 111
# Augmenting image 112
# Augmenting image 113
# Augmenting image 114
# Augmenting image 115
# Augmenting image 116
# Augmenting image 117
# Augmenting image 118
# Augmenting image 119
# Augmenting image 120
# Augmenting image 121
# Augmenting image 122
# Augmenting image 123
# Augmenting image 124
# Augmenting image 125
# Augmenting image 126
# Augmenting image 127
# Augmenting image 128
# Augmenting image 129
# Augmenting image 130
# Augmenting image 131
# Augmenting image 132
# Augmenting image 133
# Augmenting image 134
# Augmenting image 135
# Augmenting Tomato___Late_blight with 119 images
# In total we ll have 1710 images
# -------------------
# Augmenting image 1
# Augmenting image 2
# Augmenting image 3
# Augmenting image 4
# Augmenting image 5
# Augmenting image 6
# Augmenting image 7
# Augmenting image 8
# Augmenting image 9
# Augmenting image 10
# Augmenting image 11
# Augmenting image 12
# Augmenting image 13
# Augmenting image 14
# Augmenting image 15
# Augmenting image 16
# Augmenting image 17
# Augmenting image 18
# Augmenting image 19
# Augmenting image 20
# Augmenting image 21
# Augmenting image 22
# Augmenting image 23
# Augmenting image 24
# Augmenting image 25
# Augmenting image 26
# Augmenting image 27
# Augmenting image 28
# Augmenting image 29
# Augmenting image 30
# Augmenting image 31
# Augmenting image 32
# Augmenting image 33
# Augmenting image 34
# Augmenting image 35
# Augmenting image 36
# Augmenting image 37
# Augmenting image 38
# Augmenting image 39
# Augmenting image 40
# Augmenting image 41
# Augmenting image 42
# Augmenting image 43
# Augmenting image 44
# Augmenting image 45
# Augmenting image 46
# Augmenting image 47
# Augmenting image 48
# Augmenting image 49
# Augmenting image 50
# Augmenting image 51
# Augmenting image 52
# Augmenting image 53
# Augmenting image 54
# Augmenting image 55
# Augmenting image 56
# Augmenting image 57
# Augmenting image 58
# Augmenting image 59
# Augmenting image 60
# Augmenting image 61
# Augmenting image 62
# Augmenting image 63
# Augmenting image 64
# Augmenting image 65
# Augmenting image 66
# Augmenting image 67
# Augmenting image 68
# Augmenting image 69
# Augmenting image 70
# Augmenting image 71
# Augmenting image 72
# Augmenting image 73
# Augmenting image 74
# Augmenting image 75
# Augmenting image 76
# Augmenting image 77
# Augmenting image 78
# Augmenting image 79
# Augmenting image 80
# Augmenting image 81
# Augmenting image 82
# Augmenting image 83
# Augmenting image 84
# Augmenting image 85
# Augmenting image 86
# Augmenting image 87
# Augmenting image 88
# Augmenting image 89
# Augmenting image 90
# Augmenting image 91
# Augmenting image 92
# Augmenting image 93
# Augmenting image 94
# Augmenting image 95
# Augmenting image 96
# Augmenting image 97
# Augmenting image 98
# Augmenting image 99
# Augmenting image 100
# Augmenting image 101
# Augmenting image 102
# Augmenting image 103
# Augmenting image 104
# Augmenting image 105
# Augmenting image 106
# Augmenting image 107
# Augmenting image 108
# Augmenting image 109
# Augmenting image 110
# Augmenting image 111
# Augmenting image 112
# Augmenting image 113
# Augmenting image 114
# Augmenting image 115
# Augmenting image 116
# Augmenting image 117
# Augmenting image 118
# Augmenting image 119
# Augmenting Tomato___Leaf_Mold with 207 images
# In total we ll have 999 images
# -------------------
# Augmenting image 1
# Augmenting image 2
# Augmenting image 3
# Augmenting image 4
# Augmenting image 5
# Augmenting image 6
# Augmenting image 7
# Augmenting image 8
# Augmenting image 9
# Augmenting image 10
# Augmenting image 11
# Augmenting image 12
# Augmenting image 13
# Augmenting image 14
# Augmenting image 15
# Augmenting image 16
# Augmenting image 17
# Augmenting image 18
# Augmenting image 19
# Augmenting image 20
# Augmenting image 21
# Augmenting image 22
# Augmenting image 23
# Augmenting image 24
# Augmenting image 25
# Augmenting image 26
# Augmenting image 27
# Augmenting image 28
# Augmenting image 29
# Augmenting image 30
# Augmenting image 31
# Augmenting image 32
# Augmenting image 33
# Augmenting image 34
# Augmenting image 35
# Augmenting image 36
# Augmenting image 37
# Augmenting image 38
# Augmenting image 39
# Augmenting image 40
# Augmenting image 41
# Augmenting image 42
# Augmenting image 43
# Augmenting image 44
# Augmenting image 45
# Augmenting image 46
# Augmenting image 47
# Augmenting image 48
# Augmenting image 49
# Augmenting image 50
# Augmenting image 51
# Augmenting image 52
# Augmenting image 53
# Augmenting image 54
# Augmenting image 55
# Augmenting image 56
# Augmenting image 57
# Augmenting image 58
# Augmenting image 59
# Augmenting image 60
# Augmenting image 61
# Augmenting image 62
# Augmenting image 63
# Augmenting image 64
# Augmenting image 65
# Augmenting image 66
# Augmenting image 67
# Augmenting image 68
# Augmenting image 69
# Augmenting image 70
# Augmenting image 71
# Augmenting image 72
# Augmenting image 73
# Augmenting image 74
# Augmenting image 75
# Augmenting image 76
# Augmenting image 77
# Augmenting image 78
# Augmenting image 79
# Augmenting image 80
# Augmenting image 81
# Augmenting image 82
# Augmenting image 83
# Augmenting image 84
# Augmenting image 85
# Augmenting image 86
# Augmenting image 87
# Augmenting image 88
# Augmenting image 89
# Augmenting image 90
# Augmenting image 91
# Augmenting image 92
# Augmenting image 93
# Augmenting image 94
# Augmenting image 95
# Augmenting image 96
# Augmenting image 97
# Augmenting image 98
# Augmenting image 99
# Augmenting image 100
# Augmenting image 101
# Augmenting image 102
# Augmenting image 103
# Augmenting image 104
# Augmenting image 105
# Augmenting image 106
# Augmenting image 107
# Augmenting image 108
# Augmenting image 109
# Augmenting image 110
# Augmenting image 111
# Augmenting image 112
# Augmenting image 113
# Augmenting image 114
# Augmenting image 115
# Augmenting image 116
# Augmenting image 117
# Augmenting image 118
# Augmenting image 119
# Augmenting image 120
# Augmenting image 121
# Augmenting image 122
# Augmenting image 123
# Augmenting image 124
# Augmenting image 125
# Augmenting image 126
# Augmenting image 127
# Augmenting image 128
# Augmenting image 129
# Augmenting image 130
# Augmenting image 131
# Augmenting image 132
# Augmenting image 133
# Augmenting image 134
# Augmenting image 135
# Augmenting image 136
# Augmenting image 137
# Augmenting image 138
# Augmenting image 139
# Augmenting image 140
# Augmenting image 141
# Augmenting image 142
# Augmenting image 143
# Augmenting image 144
# Augmenting image 145
# Augmenting image 146
# Augmenting image 147
# Augmenting image 148
# Augmenting image 149
# Augmenting image 150
# Augmenting image 151
# Augmenting image 152
# Augmenting image 153
# Augmenting image 154
# Augmenting image 155
# Augmenting image 156
# Augmenting image 157
# Augmenting image 158
# Augmenting image 159
# Augmenting image 160
# Augmenting image 161
# Augmenting image 162
# Augmenting image 163
# Augmenting image 164
# Augmenting image 165
# Augmenting image 166
# Augmenting image 167
# Augmenting image 168
# Augmenting image 169
# Augmenting image 170
# Augmenting image 171
# Augmenting image 172
# Augmenting image 173
# Augmenting image 174
# Augmenting image 175
# Augmenting image 176
# Augmenting image 177
# Augmenting image 178
# Augmenting image 179
# Augmenting image 180
# Augmenting image 181
# Augmenting image 182
# Augmenting image 183
# Augmenting image 184
# Augmenting image 185
# Augmenting image 186
# Augmenting image 187
# Augmenting image 188
# Augmenting image 189
# Augmenting image 190
# Augmenting image 191
# Augmenting image 192
# Augmenting image 193
# Augmenting image 194
# Augmenting image 195
# Augmenting image 196
# Augmenting image 197
# Augmenting image 198
# Augmenting image 199
# Augmenting image 200
# Augmenting image 201
# Augmenting image 202
# Augmenting image 203
# Augmenting image 204
# Augmenting image 205
# Augmenting image 206
# Augmenting image 207
# Augmenting Tomato___Septoria_leaf_spot with 293 images
# In total we ll have 1771 images
# -------------------
# Augmenting image 1
# Augmenting image 2
# Augmenting image 3
# Augmenting image 4
# Augmenting image 5
# Augmenting image 6
# Augmenting image 7
# Augmenting image 8
# Augmenting image 9
# Augmenting image 10
# Augmenting image 11
# Augmenting image 12
# Augmenting image 13
# Augmenting image 14
# Augmenting image 15
# Augmenting image 16
# Augmenting image 17
# Augmenting image 18
# Augmenting image 19
# Augmenting image 20
# Augmenting image 21
# Augmenting image 22
# Augmenting image 23
# Augmenting image 24
# Augmenting image 25
# Augmenting image 26
# Augmenting image 27
# Augmenting image 28
# Augmenting image 29
# Augmenting image 30
# Augmenting image 31
# Augmenting image 32
# Augmenting image 33
# Augmenting image 34
# Augmenting image 35
# Augmenting image 36
# Augmenting image 37
# Augmenting image 38
# Augmenting image 39
# Augmenting image 40
# Augmenting image 41
# Augmenting image 42
# Augmenting image 43
# Augmenting image 44
# Augmenting image 45
# Augmenting image 46
# Augmenting image 47
# Augmenting image 48
# Augmenting image 49
# Augmenting image 50
# Augmenting image 51
# Augmenting image 52
# Augmenting image 53
# Augmenting image 54
# Augmenting image 55
# Augmenting image 56
# Augmenting image 57
# Augmenting image 58
# Augmenting image 59
# Augmenting image 60
# Augmenting image 61
# Augmenting image 62
# Augmenting image 63
# Augmenting image 64
# Augmenting image 65
# Augmenting image 66
# Augmenting image 67
# Augmenting image 68
# Augmenting image 69
# Augmenting image 70
# Augmenting image 71
# Augmenting image 72
# Augmenting image 73
# Augmenting image 74
# Augmenting image 75
# Augmenting image 76
# Augmenting image 77
# Augmenting image 78
# Augmenting image 79
# Augmenting image 80
# Augmenting image 81
# Augmenting image 82
# Augmenting image 83
# Augmenting image 84
# Augmenting image 85
# Augmenting image 86
# Augmenting image 87
# Augmenting image 88
# Augmenting image 89
# Augmenting image 90
# Augmenting image 91
# Augmenting image 92
# Augmenting image 93
# Augmenting image 94
# Augmenting image 95
# Augmenting image 96
# Augmenting image 97
# Augmenting image 98
# Augmenting image 99
# Augmenting image 100
# Augmenting image 101
# Augmenting image 102
# Augmenting image 103
# Augmenting image 104
# Augmenting image 105
# Augmenting image 106
# Augmenting image 107
# Augmenting image 108
# Augmenting image 109
# Augmenting image 110
# Augmenting image 111
# Augmenting image 112
# Augmenting image 113
# Augmenting image 114
# Augmenting image 115
# Augmenting image 116
# Augmenting image 117
# Augmenting image 118
# Augmenting image 119
# Augmenting image 120
# Augmenting image 121
# Augmenting image 122
# Augmenting image 123
# Augmenting image 124
# Augmenting image 125
# Augmenting image 126
# Augmenting image 127
# Augmenting image 128
# Augmenting image 129
# Augmenting image 130
# Augmenting image 131
# Augmenting image 132
# Augmenting image 133
# Augmenting image 134
# Augmenting image 135
# Augmenting image 136
# Augmenting image 137
# Augmenting image 138
# Augmenting image 139
# Augmenting image 140
# Augmenting image 141
# Augmenting image 142
# Augmenting image 143
# Augmenting image 144
# Augmenting image 145
# Augmenting image 146
# Augmenting image 147
# Augmenting image 148
# Augmenting image 149
# Augmenting image 150
# Augmenting image 151
# Augmenting image 152
# Augmenting image 153
# Augmenting image 154
# Augmenting image 155
# Augmenting image 156
# Augmenting image 157
# Augmenting image 158
# Augmenting image 159
# Augmenting image 160
# Augmenting image 161
# Augmenting image 162
# Augmenting image 163
# Augmenting image 164
# Augmenting image 165
# Augmenting image 166
# Augmenting image 167
# Augmenting image 168
# Augmenting image 169
# Augmenting image 170
# Augmenting image 171
# Augmenting image 172
# Augmenting image 173
# Augmenting image 174
# Augmenting image 175
# Augmenting image 176
# Augmenting image 177
# Augmenting image 178
# Augmenting image 179
# Augmenting image 180
# Augmenting image 181
# Augmenting image 182
# Augmenting image 183
# Augmenting image 184
# Augmenting image 185
# Augmenting image 186
# Augmenting image 187
# Augmenting image 188
# Augmenting image 189
# Augmenting image 190
# Augmenting image 191
# Augmenting image 192
# Augmenting image 193
# Augmenting image 194
# Augmenting image 195
# Augmenting image 196
# Augmenting image 197
# Augmenting image 198
# Augmenting image 199
# Augmenting image 200
# Augmenting image 201
# Augmenting image 202
# Augmenting image 203
# Augmenting image 204
# Augmenting image 205
# Augmenting image 206
# Augmenting image 207
# Augmenting image 208
# Augmenting image 209
# Augmenting image 210
# Augmenting image 211
# Augmenting image 212
# Augmenting image 213
# Augmenting image 214
# Augmenting image 215
# Augmenting image 216
# Augmenting image 217
# Augmenting image 218
# Augmenting image 219
# Augmenting image 220
# Augmenting image 221
# Augmenting image 222
# Augmenting image 223
# Augmenting image 224
# Augmenting image 225
# Augmenting image 226
# Augmenting image 227
# Augmenting image 228
# Augmenting image 229
# Augmenting image 230
# Augmenting image 231
# Augmenting image 232
# Augmenting image 233
# Augmenting image 234
# Augmenting image 235
# Augmenting image 236
# Augmenting image 237
# Augmenting image 238
# Augmenting image 239
# Augmenting image 240
# Augmenting image 241
# Augmenting image 242
# Augmenting image 243
# Augmenting image 244
# Augmenting image 245
# Augmenting image 246
# Augmenting image 247
# Augmenting image 248
# Augmenting image 249
# Augmenting image 250
# Augmenting image 251
# Augmenting image 252
# Augmenting image 253
# Augmenting image 254
# Augmenting image 255
# Augmenting image 256
# Augmenting image 257
# Augmenting image 258
# Augmenting image 259
# Augmenting image 260
# Augmenting image 261
# Augmenting image 262
# Augmenting image 263
# Augmenting image 264
# Augmenting image 265
# Augmenting image 266
# Augmenting image 267
# Augmenting image 268
# Augmenting image 269
# Augmenting image 270
# Augmenting image 271
# Augmenting image 272
# Augmenting image 273
# Augmenting image 274
# Augmenting image 275
# Augmenting image 276
# Augmenting image 277
# Augmenting image 278
# Augmenting image 279
# Augmenting image 280
# Augmenting image 281
# Augmenting image 282
# Augmenting image 283
# Augmenting image 284
# Augmenting image 285
# Augmenting image 286
# Augmenting image 287
# Augmenting image 288
# Augmenting image 289
# Augmenting image 290
# Augmenting image 291
# Augmenting image 292
# Augmenting image 293
# Augmenting Tomato___Tomato_Yellow_Leaf_Curl_Virus with 752 images
# In total we ll have 4930 images
# -------------------
# Augmenting image 1
# Augmenting image 2
# Augmenting image 3
# Augmenting image 4
# Augmenting image 5
# Augmenting image 6
# Augmenting image 7
# Augmenting image 8
# Augmenting image 9
# Augmenting image 10
# Augmenting image 11
# Augmenting image 12
# Augmenting image 13
# Augmenting image 14
# Augmenting image 15
# Augmenting image 16
# Augmenting image 17
# Augmenting image 18
# Augmenting image 19
# Augmenting image 20
# Augmenting image 21
# Augmenting image 22
# Augmenting image 23
# Augmenting image 24
# Augmenting image 25
# Augmenting image 26
# Augmenting image 27
# Augmenting image 28
# Augmenting image 29
# Augmenting image 30
# Augmenting image 31
# Augmenting image 32
# Augmenting image 33
# Augmenting image 34
# Augmenting image 35
# Augmenting image 36
# Augmenting image 37
# Augmenting image 38
# Augmenting image 39
# Augmenting image 40
# Augmenting image 41
# Augmenting image 42
# Augmenting image 43
# Augmenting image 44
# Augmenting image 45
# Augmenting image 46
# Augmenting image 47
# Augmenting image 48
# Augmenting image 49
# Augmenting image 50
# Augmenting image 51
# Augmenting image 52
# Augmenting image 53
# Augmenting image 54
# Augmenting image 55
# Augmenting image 56
# Augmenting image 57
# Augmenting image 58
# Augmenting image 59
# Augmenting image 60
# Augmenting image 61
# Augmenting image 62
# Augmenting image 63
# Augmenting image 64
# Augmenting image 65
# Augmenting image 66
# Augmenting image 67
# Augmenting image 68
# Augmenting image 69
# Augmenting image 70
# Augmenting image 71
# Augmenting image 72
# Augmenting image 73
# Augmenting image 74
# Augmenting image 75
# Augmenting image 76
# Augmenting image 77
# Augmenting image 78
# Augmenting image 79
# Augmenting image 80
# Augmenting image 81
# Augmenting image 82
# Augmenting image 83
# Augmenting image 84
# Augmenting image 85
# Augmenting image 86
# Augmenting image 87
# Augmenting image 88
# Augmenting image 89
# Augmenting image 90
# Augmenting image 91
# Augmenting image 92
# Augmenting image 93
# Augmenting image 94
# Augmenting image 95
# Augmenting image 96
# Augmenting image 97
# Augmenting image 98
# Augmenting image 99
# Augmenting image 100
# Augmenting image 101
# Augmenting image 102
# Augmenting image 103
# Augmenting image 104
# Augmenting image 105
# Augmenting image 106
# Augmenting image 107
# Augmenting image 108
# Augmenting image 109
# Augmenting image 110
# Augmenting image 111
# Augmenting image 112
# Augmenting image 113
# Augmenting image 114
# Augmenting image 115
# Augmenting image 116
# Augmenting image 117
# Augmenting image 118
# Augmenting image 119
# Augmenting image 120
# Augmenting image 121
# Augmenting image 122
# Augmenting image 123
# Augmenting image 124
# Augmenting image 125
# Augmenting image 126
# Augmenting image 127
# Augmenting image 128
# Augmenting image 129
# Augmenting image 130
# Augmenting image 131
# Augmenting image 132
# Augmenting image 133
# Augmenting image 134
# Augmenting image 135
# Augmenting image 136
# Augmenting image 137
# Augmenting image 138
# Augmenting image 139
# Augmenting image 140
# Augmenting image 141
# Augmenting image 142
# Augmenting image 143
# Augmenting image 144
# Augmenting image 145
# Augmenting image 146
# Augmenting image 147
# Augmenting image 148
# Augmenting image 149
# Augmenting image 150
# Augmenting image 151
# Augmenting image 152
# Augmenting image 153
# Augmenting image 154
# Augmenting image 155
# Augmenting image 156
# Augmenting image 157
# Augmenting image 158
# Augmenting image 159
# Augmenting image 160
# Augmenting image 161
# Augmenting image 162
# Augmenting image 163
# Augmenting image 164
# Augmenting image 165
# Augmenting image 166
# Augmenting image 167
# Augmenting image 168
# Augmenting image 169
# Augmenting image 170
# Augmenting image 171
# Augmenting image 172
# Augmenting image 173
# Augmenting image 174
# Augmenting image 175
# Augmenting image 176
# Augmenting image 177
# Augmenting image 178
# Augmenting image 179
# Augmenting image 180
# Augmenting image 181
# Augmenting image 182
# Augmenting image 183
# Augmenting image 184
# Augmenting image 185
# Augmenting image 186
# Augmenting image 187
# Augmenting image 188
# Augmenting image 189
# Augmenting image 190
# Augmenting image 191
# Augmenting image 192
# Augmenting image 193
# Augmenting image 194
# Augmenting image 195
# Augmenting image 196
# Augmenting image 197
# Augmenting image 198
# Augmenting image 199
# Augmenting image 200
# Augmenting image 201
# Augmenting image 202
# Augmenting image 203
# Augmenting image 204
# Augmenting image 205
# Augmenting image 206
# Augmenting image 207
# Augmenting image 208
# Augmenting image 209
# Augmenting image 210
# Augmenting image 211
# Augmenting image 212
# Augmenting image 213
# Augmenting image 214
# Augmenting image 215
# Augmenting image 216
# Augmenting image 217
# Augmenting image 218
# Augmenting image 219
# Augmenting image 220
# Augmenting image 221
# Augmenting image 222
# Augmenting image 223
# Augmenting image 224
# Augmenting image 225
# Augmenting image 226
# Augmenting image 227
# Augmenting image 228
# Augmenting image 229
# Augmenting image 230
# Augmenting image 231
# Augmenting image 232
# Augmenting image 233
# Augmenting image 234
# Augmenting image 235
# Augmenting image 236
# Augmenting image 237
# Augmenting image 238
# Augmenting image 239
# Augmenting image 240
# Augmenting image 241
# Augmenting image 242
# Augmenting image 243
# Augmenting image 244
# Augmenting image 245
# Augmenting image 246
# Augmenting image 247
# Augmenting image 248
# Augmenting image 249
# Augmenting image 250
# Augmenting image 251
# Augmenting image 252
# Augmenting image 253
# Augmenting image 254
# Augmenting image 255
# Augmenting image 256
# Augmenting image 257
# Augmenting image 258
# Augmenting image 259
# Augmenting image 260
# Augmenting image 261
# Augmenting image 262
# Augmenting image 263
# Augmenting image 264
# Augmenting image 265
# Augmenting image 266
# Augmenting image 267
# Augmenting image 268
# Augmenting image 269
# Augmenting image 270
# Augmenting image 271
# Augmenting image 272
# Augmenting image 273
# Augmenting image 274
# Augmenting image 275
# Augmenting image 276
# Augmenting image 277
# Augmenting image 278
# Augmenting image 279
# Augmenting image 280
# Augmenting image 281
# Augmenting image 282
# Augmenting image 283
# Augmenting image 284
# Augmenting image 285
# Augmenting image 286
# Augmenting image 287
# Augmenting image 288
# Augmenting image 289
# Augmenting image 290
# Augmenting image 291
# Augmenting image 292
# Augmenting image 293
# Augmenting image 294
# Augmenting image 295
# Augmenting image 296
# Augmenting image 297
# Augmenting image 298
# Augmenting image 299
# Augmenting image 300
# Augmenting image 301
# Augmenting image 302
# Augmenting image 303
# Augmenting image 304
# Augmenting image 305
# Augmenting image 306
# Augmenting image 307
# Augmenting image 308
# Augmenting image 309
# Augmenting image 310
# Augmenting image 311
# Augmenting image 312
# Augmenting image 313
# Augmenting image 314
# Augmenting image 315
# Augmenting image 316
# Augmenting image 317
# Augmenting image 318
# Augmenting image 319
# Augmenting image 320
# Augmenting image 321
# Augmenting image 322
# Augmenting image 323
# Augmenting image 324
# Augmenting image 325
# Augmenting image 326
# Augmenting image 327
# Augmenting image 328
# Augmenting image 329
# Augmenting image 330
# Augmenting image 331
# Augmenting image 332
# Augmenting image 333
# Augmenting image 334
# Augmenting image 335
# Augmenting image 336
# Augmenting image 337
# Augmenting image 338
# Augmenting image 339
# Augmenting image 340
# Augmenting image 341
# Augmenting image 342
# Augmenting image 343
# Augmenting image 344
# Augmenting image 345
# Augmenting image 346
# Augmenting image 347
# Augmenting image 348
# Augmenting image 349
# Augmenting image 350
# Augmenting image 351
# Augmenting image 352
# Augmenting image 353
# Augmenting image 354
# Augmenting image 355
# Augmenting image 356
# Augmenting image 357
# Augmenting image 358
# Augmenting image 359
# Augmenting image 360
# Augmenting image 361
# Augmenting image 362
# Augmenting image 363
# Augmenting image 364
# Augmenting image 365
# Augmenting image 366
# Augmenting image 367
# Augmenting image 368
# Augmenting image 369
# Augmenting image 370
# Augmenting image 371
# Augmenting image 372
# Augmenting image 373
# Augmenting image 374
# Augmenting image 375
# Augmenting image 376
# Augmenting image 377
# Augmenting image 378
# Augmenting image 379
# Augmenting image 380
# Augmenting image 381
# Augmenting image 382
# Augmenting image 383
# Augmenting image 384
# Augmenting image 385
# Augmenting image 386
# Augmenting image 387
# Augmenting image 388
# Augmenting image 389
# Augmenting image 390
# Augmenting image 391
# Augmenting image 392
# Augmenting image 393
# Augmenting image 394
# Augmenting image 395
# Augmenting image 396
# Augmenting image 397
# Augmenting image 398
# Augmenting image 399
# Augmenting image 400
# Augmenting image 401
# Augmenting image 402
# Augmenting image 403
# Augmenting image 404
# Augmenting image 405
# Augmenting image 406
# Augmenting image 407
# Augmenting image 408
# Augmenting image 409
# Augmenting image 410
# Augmenting image 411
# Augmenting image 412
# Augmenting image 413
# Augmenting image 414
# Augmenting image 415
# Augmenting image 416
# Augmenting image 417
# Augmenting image 418
# Augmenting image 419
# Augmenting image 420
# Augmenting image 421
# Augmenting image 422
# Augmenting image 423
# Augmenting image 424
# Augmenting image 425
# Augmenting image 426
# Augmenting image 427
# Augmenting image 428
# Augmenting image 429
# Augmenting image 430
# Augmenting image 431
# Augmenting image 432
# Augmenting image 433
# Augmenting image 434
# Augmenting image 435
# Augmenting image 436
# Augmenting image 437
# Augmenting image 438
# Augmenting image 439
# Augmenting image 440
# Augmenting image 441
# Augmenting image 442
# Augmenting image 443
# Augmenting image 444
# Augmenting image 445
# Augmenting image 446
# Augmenting image 447
# Augmenting image 448
# Augmenting image 449
# Augmenting image 450
# Augmenting image 451
# Augmenting image 452
# Augmenting image 453
# Augmenting image 454
# Augmenting image 455
# Augmenting image 456
# Augmenting image 457
# Augmenting image 458
# Augmenting image 459
# Augmenting image 460
# Augmenting image 461
# Augmenting image 462
# Augmenting image 463
# Augmenting image 464
# Augmenting image 465
# Augmenting image 466
# Augmenting image 467
# Augmenting image 468
# Augmenting image 469
# Augmenting image 470
# Augmenting image 471
# Augmenting image 472
# Augmenting image 473
# Augmenting image 474
# Augmenting image 475
# Augmenting image 476
# Augmenting image 477
# Augmenting image 478
# Augmenting image 479
# Augmenting image 480
# Augmenting image 481
# Augmenting image 482
# Augmenting image 483
# Augmenting image 484
# Augmenting image 485
# Augmenting image 486
# Augmenting image 487
# Augmenting image 488
# Augmenting image 489
# Augmenting image 490
# Augmenting image 491
# Augmenting image 492
# Augmenting image 493
# Augmenting image 494
# Augmenting image 495
# Augmenting image 496
# Augmenting image 497
# Augmenting image 498
# Augmenting image 499
# Augmenting image 500
# Augmenting image 501
# Augmenting image 502
# Augmenting image 503
# Augmenting image 504
# Augmenting image 505
# Augmenting image 506
# Augmenting image 507
# Augmenting image 508
# Augmenting image 509
# Augmenting image 510
# Augmenting image 511
# Augmenting image 512
# Augmenting image 513
# Augmenting image 514
# Augmenting image 515
# Augmenting image 516
# Augmenting image 517
# Augmenting image 518
# Augmenting image 519
# Augmenting image 520
# Augmenting image 521
# Augmenting image 522
# Augmenting image 523
# Augmenting image 524
# Augmenting image 525
# Augmenting image 526
# Augmenting image 527
# Augmenting image 528
# Augmenting image 529
# Augmenting image 530
# Augmenting image 531
# Augmenting image 532
# Augmenting image 533
# Augmenting image 534
# Augmenting image 535
# Augmenting image 536
# Augmenting image 537
# Augmenting image 538
# Augmenting image 539
# Augmenting image 540
# Augmenting image 541
# Augmenting image 542
# Augmenting image 543
# Augmenting image 544
# Augmenting image 545
# Augmenting image 546
# Augmenting image 547
# Augmenting image 548
# Augmenting image 549
# Augmenting image 550
# Augmenting image 551
# Augmenting image 552
# Augmenting image 553
# Augmenting image 554
# Augmenting image 555
# Augmenting image 556
# Augmenting image 557
# Augmenting image 558
# Augmenting image 559
# Augmenting image 560
# Augmenting image 561
# Augmenting image 562
# Augmenting image 563
# Augmenting image 564
# Augmenting image 565
# Augmenting image 566
# Augmenting image 567
# Augmenting image 568
# Augmenting image 569
# Augmenting image 570
# Augmenting image 571
# Augmenting image 572
# Augmenting image 573
# Augmenting image 574
# Augmenting image 575
# Augmenting image 576
# Augmenting image 577
# Augmenting image 578
# Augmenting image 579
# Augmenting image 580
# Augmenting image 581
# Augmenting image 582
# Augmenting image 583
# Augmenting image 584
# Augmenting image 585
# Augmenting image 586
# Augmenting image 587
# Augmenting image 588
# Augmenting image 589
# Augmenting image 590
# Augmenting image 591
# Augmenting image 592
# Augmenting image 593
# Augmenting image 594
# Augmenting image 595
# Augmenting image 596
# Augmenting image 597
# Augmenting image 598
# Augmenting image 599
# Augmenting image 600
# Augmenting image 601
# Augmenting image 602
# Augmenting image 603
# Augmenting image 604
# Augmenting image 605
# Augmenting image 606
# Augmenting image 607
# Augmenting image 608
# Augmenting image 609
# Augmenting image 610
# Augmenting image 611
# Augmenting image 612
# Augmenting image 613
# Augmenting image 614
# Augmenting image 615
# Augmenting image 616
# Augmenting image 617
# Augmenting image 618
# Augmenting image 619
# Augmenting image 620
# Augmenting image 621
# Augmenting image 622
# Augmenting image 623
# Augmenting image 624
# Augmenting image 625
# Augmenting image 626
# Augmenting image 627
# Augmenting image 628
# Augmenting image 629
# Augmenting image 630
# Augmenting image 631
# Augmenting image 632
# Augmenting image 633
# Augmenting image 634
# Augmenting image 635
# Augmenting image 636
# Augmenting image 637
# Augmenting image 638
# Augmenting image 639
# Augmenting image 640
# Augmenting image 641
# Augmenting image 642
# Augmenting image 643
# Augmenting image 644
# Augmenting image 645
# Augmenting image 646
# Augmenting image 647
# Augmenting image 648
# Augmenting image 649
# Augmenting image 650
# Augmenting image 651
# Augmenting image 652
# Augmenting image 653
# Augmenting image 654
# Augmenting image 655
# Augmenting image 656
# Augmenting image 657
# Augmenting image 658
# Augmenting image 659
# Augmenting image 660
# Augmenting image 661
# Augmenting image 662
# Augmenting image 663
# Augmenting image 664
# Augmenting image 665
# Augmenting image 666
# Augmenting image 667
# Augmenting image 668
# Augmenting image 669
# Augmenting image 670
# Augmenting image 671
# Augmenting image 672
# Augmenting image 673
# Augmenting image 674
# Augmenting image 675
# Augmenting image 676
# Augmenting image 677
# Augmenting image 678
# Augmenting image 679
# Augmenting image 680
# Augmenting image 681
# Augmenting image 682
# Augmenting image 683
# Augmenting image 684
# Augmenting image 685
# Augmenting image 686
# Augmenting image 687
# Augmenting image 688
# Augmenting image 689
# Augmenting image 690
# Augmenting image 691
# Augmenting image 692
# Augmenting image 693
# Augmenting image 694
# Augmenting image 695
# Augmenting image 696
# Augmenting image 697
# Augmenting image 698
# Augmenting image 699
# Augmenting image 700
# Augmenting image 701
# Augmenting image 702
# Augmenting image 703
# Augmenting image 704
# Augmenting image 705
# Augmenting image 706
# Augmenting image 707
# Augmenting image 708
# Augmenting image 709
# Augmenting image 710
# Augmenting image 711
# Augmenting image 712
# Augmenting image 713
# Augmenting image 714
# Augmenting image 715
# Augmenting image 716
# Augmenting image 717
# Augmenting image 718
# Augmenting image 719
# Augmenting image 720
# Augmenting image 721
# Augmenting image 722
# Augmenting image 723
# Augmenting image 724
# Augmenting image 725
# Augmenting image 726
# Augmenting image 727
# Augmenting image 728
# Augmenting image 729
# Augmenting image 730
# Augmenting image 731
# Augmenting image 732
# Augmenting image 733
# Augmenting image 734
# Augmenting image 735
# Augmenting image 736
# Augmenting image 737
# Augmenting image 738
# Augmenting image 739
# Augmenting image 740
# Augmenting image 741
# Augmenting image 742
# Augmenting image 743
# Augmenting image 744
# Augmenting image 745
# Augmenting image 746
# Augmenting image 747
# Augmenting image 748
# Augmenting image 749
# Augmenting image 750
# Augmenting image 751
# Augmenting image 752
# Augmenting Tomato___Tomato_mosaic_virus with 217 images
# In total we ll have 509 images
# -------------------
# Augmenting image 1
# Augmenting image 2
# Augmenting image 3
# Augmenting image 4
# Augmenting image 5
# Augmenting image 6
# Augmenting image 7
# Augmenting image 8
# Augmenting image 9
# Augmenting image 10
# Augmenting image 11
# Augmenting image 12
# Augmenting image 13
# Augmenting image 14
# Augmenting image 15
# Augmenting image 16
# Augmenting image 17
# Augmenting image 18
# Augmenting image 19
# Augmenting image 20
# Augmenting image 21
# Augmenting image 22
# Augmenting image 23
# Augmenting image 24
# Augmenting image 25
# Augmenting image 26
# Augmenting image 27
# Augmenting image 28
# Augmenting image 29
# Augmenting image 30
# Augmenting image 31
# Augmenting image 32
# Augmenting image 33
# Augmenting image 34
# Augmenting image 35
# Augmenting image 36
# Augmenting image 37
# Augmenting image 38
# Augmenting image 39
# Augmenting image 40
# Augmenting image 41
# Augmenting image 42
# Augmenting image 43
# Augmenting image 44
# Augmenting image 45
# Augmenting image 46
# Augmenting image 47
# Augmenting image 48
# Augmenting image 49
# Augmenting image 50
# Augmenting image 51
# Augmenting image 52
# Augmenting image 53
# Augmenting image 54
# Augmenting image 55
# Augmenting image 56
# Augmenting image 57
# Augmenting image 58
# Augmenting image 59
# Augmenting image 60
# Augmenting image 61
# Augmenting image 62
# Augmenting image 63
# Augmenting image 64
# Augmenting image 65
# Augmenting image 66
# Augmenting image 67
# Augmenting image 68
# Augmenting image 69
# Augmenting image 70
# Augmenting image 71
# Augmenting image 72
# Augmenting image 73
# Augmenting image 74
# Augmenting image 75
# Augmenting image 76
# Augmenting image 77
# Augmenting image 78
# Augmenting image 79
# Augmenting image 80
# Augmenting image 81
# Augmenting image 82
# Augmenting image 83
# Augmenting image 84
# Augmenting image 85
# Augmenting image 86
# Augmenting image 87
# Augmenting image 88
# Augmenting image 89
# Augmenting image 90
# Augmenting image 91
# Augmenting image 92
# Augmenting image 93
# Augmenting image 94
# Augmenting image 95
# Augmenting image 96
# Augmenting image 97
# Augmenting image 98
# Augmenting image 99
# Augmenting image 100
# Augmenting image 101
# Augmenting image 102
# Augmenting image 103
# Augmenting image 104
# Augmenting image 105
# Augmenting image 106
# Augmenting image 107
# Augmenting image 108
# Augmenting image 109
# Augmenting image 110
# Augmenting image 111
# Augmenting image 112
# Augmenting image 113
# Augmenting image 114
# Augmenting image 115
# Augmenting image 116
# Augmenting image 117
# Augmenting image 118
# Augmenting image 119
# Augmenting image 120
# Augmenting image 121
# Augmenting image 122
# Augmenting image 123
# Augmenting image 124
# Augmenting image 125
# Augmenting image 126
# Augmenting image 127
# Augmenting image 128
# Augmenting image 129
# Augmenting image 130
# Augmenting image 131
# Augmenting image 132
# Augmenting image 133
# Augmenting image 134
# Augmenting image 135
# Augmenting image 136
# Augmenting image 137
# Augmenting image 138
# Augmenting image 139
# Augmenting image 140
# Augmenting image 141
# Augmenting image 142
# Augmenting image 143
# Augmenting image 144
# Augmenting image 145
# Augmenting image 146
# Augmenting image 147
# Augmenting image 148
# Augmenting image 149
# Augmenting image 150
# Augmenting image 151
# Augmenting image 152
# Augmenting image 153
# Augmenting image 154
# Augmenting image 155
# Augmenting image 156
# Augmenting image 157
# Augmenting image 158
# Augmenting image 159
# Augmenting image 160
# Augmenting image 161
# Augmenting image 162
# Augmenting image 163
# Augmenting image 164
# Augmenting image 165
# Augmenting image 166
# Augmenting image 167
# Augmenting image 168
# Augmenting image 169
# Augmenting image 170
# Augmenting image 171
# Augmenting image 172
# Augmenting image 173
# Augmenting image 174
# Augmenting image 175
# Augmenting image 176
# Augmenting image 177
# Augmenting image 178
# Augmenting image 179
# Augmenting image 180
# Augmenting image 181
# Augmenting image 182
# Augmenting image 183
# Augmenting image 184
# Augmenting image 185
# Augmenting image 186
# Augmenting image 187
# Augmenting image 188
# Augmenting image 189
# Augmenting image 190
# Augmenting image 191
# Augmenting image 192
# Augmenting image 193
# Augmenting image 194
# Augmenting image 195
# Augmenting image 196
# Augmenting image 197
# Augmenting image 198
# Augmenting image 199
# Augmenting image 200
# Augmenting image 201
# Augmenting image 202
# Augmenting image 203
# Augmenting image 204
# Augmenting image 205
# Augmenting image 206
# Augmenting image 207
# Augmenting image 208
# Augmenting image 209
# Augmenting image 210
# Augmenting image 211
# Augmenting image 212
# Augmenting image 213
# Augmenting image 214
# Augmenting image 215
# Augmenting image 216
# Augmenting image 217
# Augmenting Tomato___healthy with 340 images
# In total we ll have 1589 images
# -------------------
# Augmenting image 1
# Augmenting image 2
# Augmenting image 3
# Augmenting image 4
# Augmenting image 5
# Augmenting image 6
# Augmenting image 7
# Augmenting image 8
# Augmenting image 9
# Augmenting image 10
# Augmenting image 11
# Augmenting image 12
# Augmenting image 13
# Augmenting image 14
# Augmenting image 15
# Augmenting image 16
# Augmenting image 17
# Augmenting image 18
# Augmenting image 19
# Augmenting image 20
# Augmenting image 21
# Augmenting image 22
# Augmenting image 23
# Augmenting image 24
# Augmenting image 25
# Augmenting image 26
# Augmenting image 27
# Augmenting image 28
# Augmenting image 29
# Augmenting image 30
# Augmenting image 31
# Augmenting image 32
# Augmenting image 33
# Augmenting image 34
# Augmenting image 35
# Augmenting image 36
# Augmenting image 37
# Augmenting image 38
# Augmenting image 39
# Augmenting image 40
# Augmenting image 41
# Augmenting image 42
# Augmenting image 43
# Augmenting image 44
# Augmenting image 45
# Augmenting image 46
# Augmenting image 47
# Augmenting image 48
# Augmenting image 49
# Augmenting image 50
# Augmenting image 51
# Augmenting image 52
# Augmenting image 53
# Augmenting image 54
# Augmenting image 55
# Augmenting image 56
# Augmenting image 57
# Augmenting image 58
# Augmenting image 59
# Augmenting image 60
# Augmenting image 61
# Augmenting image 62
# Augmenting image 63
# Augmenting image 64
# Augmenting image 65
# Augmenting image 66
# Augmenting image 67
# Augmenting image 68
# Augmenting image 69
# Augmenting image 70
# Augmenting image 71
# Augmenting image 72
# Augmenting image 73
# Augmenting image 74
# Augmenting image 75
# Augmenting image 76
# Augmenting image 77
# Augmenting image 78
# Augmenting image 79
# Augmenting image 80
# Augmenting image 81
# Augmenting image 82
# Augmenting image 83
# Augmenting image 84
# Augmenting image 85
# Augmenting image 86
# Augmenting image 87
# Augmenting image 88
# Augmenting image 89
# Augmenting image 90
# Augmenting image 91
# Augmenting image 92
# Augmenting image 93
# Augmenting image 94
# Augmenting image 95
# Augmenting image 96
# Augmenting image 97
# Augmenting image 98
# Augmenting image 99
# Augmenting image 100
# Augmenting image 101
# Augmenting image 102
# Augmenting image 103
# Augmenting image 104
# Augmenting image 105
# Augmenting image 106
# Augmenting image 107
# Augmenting image 108
# Augmenting image 109
# Augmenting image 110
# Augmenting image 111
# Augmenting image 112
# Augmenting image 113
# Augmenting image 114
# Augmenting image 115
# Augmenting image 116
# Augmenting image 117
# Augmenting image 118
# Augmenting image 119
# Augmenting image 120
# Augmenting image 121
# Augmenting image 122
# Augmenting image 123
# Augmenting image 124
# Augmenting image 125
# Augmenting image 126
# Augmenting image 127
# Augmenting image 128
# Augmenting image 129
# Augmenting image 130
# Augmenting image 131
# Augmenting image 132
# Augmenting image 133
# Augmenting image 134
# Augmenting image 135
# Augmenting image 136
# Augmenting image 137
# Augmenting image 138
# Augmenting image 139
# Augmenting image 140
# Augmenting image 141
# Augmenting image 142
# Augmenting image 143
# Augmenting image 144
# Augmenting image 145
# Augmenting image 146
# Augmenting image 147
# Augmenting image 148
# Augmenting image 149
# Augmenting image 150
# Augmenting image 151
# Augmenting image 152
# Augmenting image 153
# Augmenting image 154
# Augmenting image 155
# Augmenting image 156
# Augmenting image 157
# Augmenting image 158
# Augmenting image 159
# Augmenting image 160
# Augmenting image 161
# Augmenting image 162
# Augmenting image 163
# Augmenting image 164
# Augmenting image 165
# Augmenting image 166
# Augmenting image 167
# Augmenting image 168
# Augmenting image 169
# Augmenting image 170
# Augmenting image 171
# Augmenting image 172
# Augmenting image 173
# Augmenting image 174
# Augmenting image 175
# Augmenting image 176
# Augmenting image 177
# Augmenting image 178
# Augmenting image 179
# Augmenting image 180
# Augmenting image 181
# Augmenting image 182
# Augmenting image 183
# Augmenting image 184
# Augmenting image 185
# Augmenting image 186
# Augmenting image 187
# Augmenting image 188
# Augmenting image 189
# Augmenting image 190
# Augmenting image 191
# Augmenting image 192
# Augmenting image 193
# Augmenting image 194
# Augmenting image 195
# Augmenting image 196
# Augmenting image 197
# Augmenting image 198
# Augmenting image 199
# Augmenting image 200
# Augmenting image 201
# Augmenting image 202
# Augmenting image 203
# Augmenting image 204
# Augmenting image 205
# Augmenting image 206
# Augmenting image 207
# Augmenting image 208
# Augmenting image 209
# Augmenting image 210
# Augmenting image 211
# Augmenting image 212
# Augmenting image 213
# Augmenting image 214
# Augmenting image 215
# Augmenting image 216
# Augmenting image 217
# Augmenting image 218
# Augmenting image 219
# Augmenting image 220
# Augmenting image 221
# Augmenting image 222
# Augmenting image 223
# Augmenting image 224
# Augmenting image 225
# Augmenting image 226
# Augmenting image 227
# Augmenting image 228
# Augmenting image 229
# Augmenting image 230
# Augmenting image 231
# Augmenting image 232
# Augmenting image 233
# Augmenting image 234
# Augmenting image 235
# Augmenting image 236
# Augmenting image 237
# Augmenting image 238
# Augmenting image 239
# Augmenting image 240
# Augmenting image 241
# Augmenting image 242
# Augmenting image 243
# Augmenting image 244
# Augmenting image 245
# Augmenting image 246
# Augmenting image 247
# Augmenting image 248
# Augmenting image 249
# Augmenting image 250
# Augmenting image 251
# Augmenting image 252
# Augmenting image 253
# Augmenting image 254
# Augmenting image 255
# Augmenting image 256
# Augmenting image 257
# Augmenting image 258
# Augmenting image 259
# Augmenting image 260
# Augmenting image 261
# Augmenting image 262
# Augmenting image 263
# Augmenting image 264
# Augmenting image 265
# Augmenting image 266
# Augmenting image 267
# Augmenting image 268
# Augmenting image 269
# Augmenting image 270
# Augmenting image 271
# Augmenting image 272
# Augmenting image 273
# Augmenting image 274
# Augmenting image 275
# Augmenting image 276
# Augmenting image 277
# Augmenting image 278
# Augmenting image 279
# Augmenting image 280
# Augmenting image 281
# Augmenting image 282
# Augmenting image 283
# Augmenting image 284
# Augmenting image 285
# Augmenting image 286
# Augmenting image 287
# Augmenting image 288
# Augmenting image 289
# Augmenting image 290
# Augmenting image 291
# Augmenting image 292
# Augmenting image 293
# Augmenting image 294
# Augmenting image 295
# Augmenting image 296
# Augmenting image 297
# Augmenting image 298
# Augmenting image 299
# Augmenting image 300
# Augmenting image 301
# Augmenting image 302
# Augmenting image 303
# Augmenting image 304
# Augmenting image 305
# Augmenting image 306
# Augmenting image 307
# Augmenting image 308
# Augmenting image 309
# Augmenting image 310
# Augmenting image 311
# Augmenting image 312
# Augmenting image 313
# Augmenting image 314
# Augmenting image 315
# Augmenting image 316
# Augmenting image 317
# Augmenting image 318
# Augmenting image 319
# Augmenting image 320
# Augmenting image 321
# Augmenting image 322
# Augmenting image 323
# Augmenting image 324
# Augmenting image 325
# Augmenting image 326
# Augmenting image 327
# Augmenting image 328
# Augmenting image 329
# Augmenting image 330
# Augmenting image 331
# Augmenting image 332
# Augmenting image 333
# Augmenting image 334
# Augmenting image 335
# Augmenting image 336
# Augmenting image 337
# Augmenting image 338
# Augmenting image 339
# Augmenting image 340
# Augmentation complete!
